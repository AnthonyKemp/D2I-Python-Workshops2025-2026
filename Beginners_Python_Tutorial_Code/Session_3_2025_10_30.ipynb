# %%
# pandas

import pandas as pd #import with an alias

filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv"

house_prices = pd.read_csv(filepath) #this is a function for csvs
# if reading Excel use pd.read_excel()
#house_prices
print(house_prices.info()) #this is a method
print(house_prices.head(10)) #this is set number of rows from the top
print(house_prices.tail(10)) #this is set number of rows from the bottom
type(house_prices) #dataframes/df - tabular data within panda
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Name                                            523 non-null    object
#  1   Period                                          523 non-null    object
#  2   House price index All property types            523 non-null    float64
#  3   Average price All property types                523 non-null    int64
#  4   Percentage change (monthly) All property types  523 non-null    float64
#  5   Percentage change (yearly) All property types   523 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 24.6+ KB
# None
#              Name   Period  House price index All property types  \
# 0  United Kingdom  1980-01                                 10.11
# ...

# %%
# pandas

import pandas as pd #import with an alias

filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"

child_data = pd.read_csv(filepath) #this is a function for csvs
# if reading Excel use pd.read_excel()
#child_data
print(child_data.info()) #this is a method
print(child_data.head(10)) #this is set number of rows from the top
#print(child_data.tail(10)) #this is set number of rows from the bottom
#type(child_data) #dataframes/df - tabular data within panda
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.5+ KB
# None
#    Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0           0  RND000215205141  A850728973744        NaN         NaN
# ...

# %%
house_prices["Period"].info() #check original type
house_prices["Period_dt"] = pd.to_datetime(house_prices["Period"],format="%Y-%m")
house_prices["Period_dt"].info() #check type has changed
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 523 entries, 0 to 522
# Series name: Period
# Non-Null Count  Dtype
# --------------  -----
# 523 non-null    object
# dtypes: object(1)
# memory usage: 4.2+ KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 523 entries, 0 to 522
# Series name: Period_dt
# Non-Null Count  Dtype
# --------------  -----
# 523 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 4.2 KB

# %%
child_data["PersonBirthDate"].info() #check original type
child_data["PersonBirthDate_dt"] = pd.to_datetime(child_data["PersonBirthDate"],format="%Y-%m-%d")
child_data["PersonBirthDate_dt"].info() #check type has changed

child_data["ExpectedPersonBirthDate"].info() #check original type
child_data["ExpectedPersonBirthDate_dt"] = pd.to_datetime(child_data["ExpectedPersonBirthDate"],format="%Y-%m-%d")
child_data["ExpectedPersonBirthDate_dt"].info() #check type has changed
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 332 entries, 0 to 331
# Series name: PersonBirthDate
# Non-Null Count  Dtype
# --------------  -----
# 332 non-null    object
# dtypes: object(1)
# memory usage: 2.7+ KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 332 entries, 0 to 331
# Series name: PersonBirthDate_dt
# Non-Null Count  Dtype
# --------------  -----
# 332 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.7 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 332 entries, 0 to 331
# Series name: ExpectedPersonBirthDate
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      object
# dtypes: object(1)
# memory usage: 2.7+ KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 332 entries, 0 to 331
# Series name: ExpectedPersonBirthDate_dt
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.7 KB

# %%
# sum, mean, median, min, max

house_prices_monthly_change_sum = house_prices["Percentage change (monthly) All property types"].sum()
print(f"The sum of Percentage change (monthly) All property types is {house_prices_monthly_change_sum}")

max_price = house_prices["Average price All property types"].max()
min_price = house_prices["Average price All property types"].min()
med_price = house_prices["Average price All property types"].median()
mean_price = house_prices["Average price All property types"].mean()
print(f"Max price: {max_price}, \nMin price: {min_price}, \nMedium price: {med_price} , \nAverage price: {mean_price}")

condition = house_prices["Average price All property types"]< mean_price
less_than_mean = house_prices[condition]

less_than_mean
# Out:
# The sum of Percentage change (monthly) All property types is 623.29
# Max price: 292187,
# Min price: 19273,
# Medium price: 97964.0 ,
# Average price: 120570.55831739961
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 269  United Kingdom  2002-06                                 59.43
# 270  United Kingdom  2002-07                                 59.90
# 271  United Kingdom  2002-08                                 61.23
# 272  United Kingdom  2002-09                                 62.72
# ...

# %%
child_data["PersonBirthDate_dt"]

collection_end = pd.to_datetime("31/03/2026", format="%d/%m/%Y")

child_data["age_delta"] = collection_end - child_data["PersonBirthDate_dt"]

child_data["age_delta"] = child_data["age_delta"] / pd.Timedelta(365.25, "d")

child_data["age_delta"] = child_data["age_delta"].astype("int")

max_age = child_data["age_delta"].max()
min_age = child_data["age_delta"].min()
median_age = child_data["age_delta"].median()
mean_age = child_data["age_delta"].mean()

print(f"Max age: {max_age}")
print(f"Min age: {min_age}")
print(f"Median age: {median_age}")
print(f"Mean age: {mean_age}")
# Out:
# Max age: 21
# Min age: 3
# Median age: 12.0
# Mean age: 12.289156626506024
